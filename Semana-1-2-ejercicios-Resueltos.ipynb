# %% [markdown]
# # Ejercicios – Semana 1

# %% [markdown]
# ## Ejercicio 1:
#
# > a. Crea 3 variables, una entera, una flotante y una cadena de texto.
#
# > b. Imprime cada una de las variables en la consola.
#
# > c. Crea una variable booleana y asignale un valor.
#
# > d. Imprime la variable booleana en la consola.

# %%
# Declaro las tres variables, con sus respectivos tipos aclarados en sus nombres

variable_entera = 23 # Guardo la variable entera en el nombre variable_entera

variable_flotante = 9.00012 # Guardo la variable flotante en el nombre variable_flotante

variable_cadena = 'Messi' # Guardo la variable cadena de texto en variable_cadena

print(variable_entera)
print(variable_flotante)
print(variable_cadena)

# Ver que si bien usé nombres que dicen el tipo de la variable, esto no tiene que ser necesariamente asi.
# Podria haber llamado dibu a la variable_entera, y julian a la variable_flotante. A efectos practicos es
# lo mismo, PERO es muy importante usar nombres en las variables que expliquen lo que tienen. Sino después 
# se vuelve muy dificil entender el codigo y seguir trabajando sobre las mismas variables.

variable_bool = False

print(variable_bool)
# Out:
# 23
# 9.00012
# Messi
# False

# %% [markdown]
# ## Ejercicio 2:
#
# > a.    Crea una variable entera llamada edad y asígnale un valor.
#
# > b.    Crea una variable flotante llamada altura y asígnale un valor.
#
# > c.    Crea una variable de texto llamada nombre y asígnale un valor.
#
# > d.    Crea una variable booleana llamada soltero y asígnale un valor.
#
# > e.    Imprime en la consola la edad, la altura, el nombre y el estado civil (soltero o no soltero).
#
# > f.    Crea una variable llamada todos_datos que sea una lista que contenga la edad, la altura, el nombre y el estado civil.
#
# > g.    Imprime la lista todos_datos en la consola.

# %%
edad = 35
altura = 1.8 # en metros
nombre = 'Angel'
soltero = False

# print() imprime todas las variables que yo le ponga dentro de la función separadas por comas.
print('Edad:',edad) # Acá puse una cadena 'Edad:' y la variable edad
print('Altura:',altura)
print('Nombre:',nombre)
print('Soltero:',soltero)

todos_datos = [edad,altura,nombre,soltero] # creo la lista que tiene guardado todas las variables.
print(todos_datos)
# Out:
# Edad: 35
# Altura: 1.8
# Nombre: Angel
# Soltero: False
# [35, 1.8, 'Angel', False]

# %% [markdown]
# ## Ejercicio 3:
#
#
# *El índice de masa corporal (IMC) se puede calcular utilizando la siguiente fórmula:*
#
# > *IMC = P / A^2*
#
# > *donde P es el peso de la persona en kilogramos y A es la altura de la misma persona en metros. La fórmula resulta en un número que se utiliza para determinar si una persona está en un peso saludable o no.*
#
# *Un IMC normal se encuentra entre 18.5 y 24.9 kg/m^2. Un IMC menor a 18.5 kg/m^2 se considera bajo peso, mientras que un IMC mayor a 25 kg/m^2 se considera sobrepeso. Un IMC mayor a 30 kg/m^2 se considera obesidad. Sin embargo, estos valores son solo una guía y no son válidos para todas las personas, especialmente aquellas con una gran cantidad de músculo o deportistas.*
#
# **Crea un programa que te pida (usando input()) las siguientes informaciones: nombre, edad, peso en kg y altura en m y que te devuelva el nombre, la edad y el índice de masa corporal de esa persona.**
#
#
# *PISTA: input() siempre devuelve siempre una cadena*

# %%
# input() promptea al usuario y guarda esa variable COMO UNA CADENA (str).
nombre = input('¿Nombre?: ')

edad_str = input('¿Edad?: ')
edad = int(edad_str)  # Como input guarda la variable como cadena, hay que 'castearla' (convertir su tipo) a entero, con la funcion int() (int=integer=entero)
                      # ¿Que pasa si el usuario introduce una palabra en vez de un numero?

peso_str = input('¿Peso (en kg)?: ') 
peso = float(peso_str) # Como input guarda la variable como cadena, hay que 'castearla' (convertir su tipo) a flotante, con la funcion float() (float=flotante)
                       # OJO! float() solo entiende cuando los decimales se separan con '.' no con ','....
                       # ¿Habrá una manera de arreglar la cadena si el usuario usó ',' (antes de pasarla por float())? ¿Y de forzar al usuario a que introduzca si o si usando '.'?

altura_str = input('¿Altura (en m)?: ')
altura = float(altura_str)

masa_corporal = peso / (altura**2)

print(f'\nNombre: {nombre}\nEdad: {altura}\nIMC: {masa_corporal}')
# Out:
# Nombre: Nahuel
# Edad: 1.78
# IMC: 31.561671506122963

# %% [markdown]
# ## Ejercicio 4:
#
# Crea un código que declare una variable con el número 5 elevado a la cuarta potencia. Luego que escriba en pantalla un mensaje que diga el tipo de variable declarada. Luego hacer lo mismo, pero cambiando el exponente a 1/2 y a una potencia negativa.

# %%
cinco_cuarta = 5**4 # declaro 5^4 en la variable cinco_cuarta
tipo_cinco_cuarta =  type(cinco_cuarta) # la función type() nos dice cual es el tipo una variable
print('cinco_cuarta:', tipo_cinco_cuarta) 

cinco_un_medio = 5**(1/2)
tipo_cinco_un_medio = type(cinco_un_medio)
print('cinco_un_medio:', tipo_cinco_un_medio) 

cinco_negativa = 5**(-1)
print('cinco_negativa:', type(cinco_negativa)) # También puedo llamar a type() directo desde adentro de print().
                                               # Al fin y al cabo type() devuelve algo que yo guardaba en una variable
                                               # transitoria (por ej. tipo_cinco_cuarta) y lo que estoy haciendo es
                                               # directamente mandarle a print() lo que devuelve type(), sin intermediarios.
# Out:
# cinco_cuarta: <class 'int'>
# cinco_un_medio: <class 'float'>
# cinco_negativa: <class 'float'>

# %% [markdown]
# ## Ejercicio 5:
#
# Crea un código que tome como parámetro una frase y sea capaz de contar el número de palabras que contiene. Haga un test con la frase: "Me gusta estudiar python en la UNSAM".
#
# Y si queremos contar los caracteres incluyendo los espacios. ¿Cómo seria?
#
# Prueba con otras frases, para eso podes usar la funcion de ingreso de valores por teclado.

# %%
print('CONTADOR DE PALABRAS\n--------------------\n')

frase = input('Introduzca una frase:\n')
print() # print() siempre agrega al final de la impresion \n entonces pasa de renglon. Si uso print() sola, simplemente saltea el renglon.

frase_como_lista = frase.split(" ") # frase.split() va retornar una lista con la frase separada en cada espacio que encuentre, o sea que cada elemento de la lista es una palabra.
palabras = len(frase_como_lista) # Si yo veo el largo de una lista que tiene todas las palabras de la frase.... ENTONCES SE CUANTAS PALABRAS TIENE LA FRASE!

# También se puede resolver todo en un reglón! Es más elegante! En python, se pueden meter funciones adentro de funciones (composicion de funciones)
# Esta bueno hacerlo, siempre y cuando no se vuelva más dificil de leer. Sino es mejor hacerlo utilizando variables intermedias.
# palabras = len(frase.split(' '))

print(f'La frase tiene {palabras} palabras.')

caracteres = len(frase)

print(f'La frase tiene {caracteres} caracteres.')
# Out:
# CONTADOR DE PALABRAS
# --------------------
#
#
# La frase tiene 2 palabras.
# La frase tiene 10 caracteres.

# %% [markdown]
# ## Ejercicio 6:
#
# Escriba un programa que reciba dos números y los compare dando como resultado verdadero o falso ante la frase: El primer número es menor que el segundo.

# %%
numero_1 = float(input('Primer numero: ')) # Solicito al usuario el primer número, y la casteo a float. Eso lo guardo en la variable numero_1.
                                           # En el ejercicio 2 hicimos esto en 2 renglones, primero guardamos el input() y despues lo 'casteamos' (convertimos) al tipo numerico que 
                                           # necesitabamos. Como ya estamos más cancheros, lo resolví en un solo renglon, metiendo a input() adentro de float() pero ESTÁ BIEN HACERLO
                                           # EN 2 LINEAS TAMBIÉN!
                                           # Si lo queremos haces en dos lineas podes hacer:
                                           # numero_1 = (input('Primer numero: '))  --> El valor ingresado será un string, puedes probar pidiendo el type
                                           # numero_1 = float(numero_1)            --> Reescribimos la variable convirtiendola de string para float. Podes probar nuevamente usando type

numero_2 = float(input('Segundo numero: '))

n1_menor_n2 = numero_1 < numero_2 # Comparo las dos variables. La comparación directamente queda guardada en la variable n1_menor_n2

print('El primer número es menor que el segundo: ', n1_menor_n2)

# %% [markdown]
# ## Ejercicio 7:
#
# Cree un programa en python que calcule el promedio entre 2 notas.

# %%
nota_1 = float(input('Nota: ')) # Solicito al usuario la nota, y la casteo (convierto el tipo) a float. Eso lo guardo en la variable nota_1
nota_2 = float(input('Nota: ')) # idem pero en nota 2

promedio = (nota_1+nota_2)/2

print('El promedio entre las 2 notas es: ', promedio)

# %% [markdown]
# ## Ejercicio 8:
#
# Escriba un programa que se utilizará para decidir si un alumno ha aprobado o no. Para ser aprobado, todos los promedios del alumno deben ser superiores a 7. Considere que el alumno cursa
# sólo tres asignaturas, y que la calificación de cada una de ellas se almacena en las siguientes variables: materia1, materia2 y materia3.

# %%
materia1 = float(input('Calificación asignatura 1: '))
materia2 = float(input('Calificación asignatura 2: '))
materia3 = float(input('Calificación asignatura 3: '))

promedio = (materia1 + materia2 + materia3)/3

aprobo = promedio > 7

print()
print('¿El alumno aprobó?: ',aprobo)

# %% [markdown]
# ## Ejercicio 9:
#
# Escriba un programa que lea input del usuario: cantidad de días, horas, minutos y segundos y que en base a esos datos, calcule el total en segundos.

# %%
dias = int(input('Dias: '))
horas = int(input('Horas: '))
minutos = int(input('Minutos: '))
segundos = int(input('Segundos: '))

dias_a_segundos = dias*24*60*60 # Convierto los dias solicitados al usuario a segundos (1 dia tiene 24 horas, cada hora tiene 60 minutos y cada minuto tiene 60 segundos),
                                # y guardo el resultado en la variable dias_a_segundos.

horas_a_segundos = horas*60*60 # Repito con horas.

minutos_a_segundos = minutos*60 # Repito con minutos.

total = dias_a_segundos + horas_a_segundos + minutos_a_segundos + segundos # Sumo todos los valores que ahora ESTÁN EN SEGUNDOS guardados en cada una de las variables.

print('Total en segundos: ',total)

# %% [markdown]
# # Ejercicio 10:
#
# Haga un programa que pregunte por el precio de una mercaderia y el porcentaje de descuento de la misma y que calcule el importe del descuento y el precio a pagar.

# %%
mercaderia = float(input('Precio: '))
porcentaje_descuento = int(input('Descuento: '))

importe_descuento = (mercaderia*porcentaje_descuento)/100 # Usando regla de 3, encuentro el descuento.

precio_pagar = mercaderia - importe_descuento # Guardo en precio_pagar el precio a pagar, que seria el descuento restado al precio de la mercaderia r

print('Importe descontado: ', importe_descuento)
print('Precio a pagar: ', precio_pagar)

# %% [markdown]
# ## Ejercicio 11:
#
# El alquiler de un auto cuesta `$3000` por día y `$220` por cada kilometro recorrido. Escriba un programa que calcule el valor a pagar dependiendo del número de días alquilado y de km total recorridos.
#
# Verifique su programa calculando el importe a pagar por un alquiler de 10 días y 400 kilometros recorridos en esos 10 días. Pruebe otros ejemplos.

# %%
numero_dias = int(input('Numero de dias de alquiler: '))
km_total = int(input('Total de km recorridos: '))

valor_pagar = numero_dias*3000 + km_total*220

print('Valor a pagar: ',valor_pagar)

# %% [markdown]
# ## Ejercicio 12:
#
# Crea un programa que calcule el área de un rectángulo.

# %%
lado_1 = float(input('Lado 1: '))
lado_2 = float(input('Lado 2: '))

area = lado_1 * lado_2

print('Area: ', area)
